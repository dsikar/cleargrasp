# %% [markdown]
# # Zivid One+ RGB

# %%
# load color.png
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
color_img = mpimg.imread('viz/color.png')
imgplot = plt.imshow(color_img)
plt.show()
# load depth.png

# convert to numpy arrays

# show dimensions

# plot

# %% [markdown]
# # Zivid One+ RGB shape

# %%
# look at numpy array data
import numpy as np
myarr_color_img = np.asarray(color_img)
print(myarr_color_img.shape)
# Out:
# (1200, 1920, 4)

# %% [markdown]
# # Zivid One+ Depth

# %%
depth_img = mpimg.imread('viz/depth.png')
imgplot = plt.imshow(depth_img)
plt.show()

# %% [markdown]
# # Zivid One+ Depth shape

# %%
import numpy as np
myarr_depth_img = np.asarray(depth_img)
print(myarr_depth_img.shape)
# Out:
# (1200, 1920, 3)

# %% [markdown]
# # Redwood RGB

# %%
color_001_img = mpimg.imread('viz/001_color.png')
imgplot = plt.imshow(color_001_img)
plt.show()

# %% [markdown]
# # Redwood RGB shape

# %%
import numpy as np
myarr_color_001_img = np.asarray(color_001_img)
print(myarr_color_001_img.shape)
# Out:
# (240, 320, 3)

# %% [markdown]
# # Redwood Depth

# %%
depth_001_img = mpimg.imread('viz/001_depth.png')
imgplot = plt.imshow(depth_001_img)
plt.show()

# %% [markdown]
# # Redwood Depth shape

# %%
import numpy as np
myarr_depth_001_img = np.asarray(depth_001_img)
print(myarr_depth_001_img.shape)
# Out:
# (240, 320)

# %% [markdown]
# # D415 RGB (from saved numpy array)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
with open('d415_color_img.npy', 'rb') as f:
        d415_color_img = np.load(f)       
plt.imshow(d415_color_img)

# %% [markdown]
# # D415 RGB (from saved numpy array) shape

# %%
print(d415_color_img.shape)
# Out:
# (720, 1280, 3)

# %% [markdown]
# # D415 Depth (from saved numpy array)

# %%
with open('d415_input_depth.npy', 'rb') as f:
        d415_input_depth = np.load(f) 
plt.imshow(d415_input_depth)

# %% [markdown]
# # D415 Depth (from saved numpy array) shape

# %%
print(d415_input_depth.shape)
# Out:
# (720, 1280)

# %% [markdown]
# # Zivid One+ RGB (from saved numpy array)

# %%
with open('zivid_color_img.npy', 'rb') as f:
        zivid_color_img = np.load(f)       
plt.imshow(zivid_color_img)

# %% [markdown]
# # Zivid One+ RGB (from saved numpy array) shape

# %%
print(zivid_color_img.shape)
# Out:
# (720, 1280, 3)

# %% [markdown]
# # Zivid One+ Depth (from saved numpy array)

# %%
with open('zivid_input_depth.npy', 'rb') as f:
        zivid_input_depth = np.load(f) 
plt.imshow(zivid_input_depth)

# %% [markdown]
# # Zivid One+ Depth (from saved numpy array) shape

# %%
print(zivid_input_depth.shape)
# Out:
# (720, 1280)

# %% [markdown]
# We were able to generate a point cloud using script viz/create-point-cloud.py using RGB and depth files viz/color.png and viz/depth.png respectively. It turns out this have shape (1200, 1920, 4) and (1200, 1920, 3) respectively. We were not able to generate a point cloud using Redwood datset files viz/001_color.png and viz/001_depth.png, with shapes (240, 320, 3) and (240, 320) respectively.
#
# The saved numpy arrays for D415 and Zivid One+, using script live_demo.py and zivid_live_demo.py have the same shape as Redwood data, i.e. (H, W, 3) for RGB and (H, W) for depth.
#
# We are none the wiser in terms of generating a point cloud from these two files. Recapping, the reason we want to do this is to perform qualitative analysis on the completed depth, by generating a point cloud of the RGB and acquired depth and comparing it to a point cloud of the RGB and predicted depth.
